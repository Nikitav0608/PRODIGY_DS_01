# %% [markdown]
# **Task 1**

# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Reading CSV file**

# %%
data_Pokemon = pd.read_csv(r'Pokemon.csv')

# %% [markdown]
# **Exploring Data**

# %%
data_Pokemon.shape
# Out:
# (800, 13)

# %%
data_Pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
data_Pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
data_Pokemon.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
data_Pokemon.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
data_Pokemon.describe(include='object')
# Out:
#              Name Type 1  Type 2
# count         800    800     414
# unique        800     18      18
# top     Bulbasaur  Water  Flying
# freq            1    112      97

# %%
data_Pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# Define the color palette
palette_color = sns.color_palette('pastel')

# Calculate value counts
df = data_Pokemon['Type 1'].value_counts()

# Plot the pie chart
plt.figure(figsize=(8, 8))  # Adjust the figure size as needed
plt.pie(df, labels=df.index, autopct='%.1f%%', labeldistance=0.9, colors=palette_color)
plt.title('Distribution of Pokemon Types')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
data_Pokemon['Legendary'].value_counts().plot(kind='bar',color='lightgreen',title='Legendary Check')
# Out:
# <Axes: title={'center': 'Legendary Check'}, xlabel='Legendary'>

# %% [markdown]
# **Distribution of Pokemons Gen-Wise**

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data = data_Pokemon,hue='Generation' , x='Generation',palette='pastel',legend='auto')
plt.title('Number of Pokemons Gen-Wise')
plt.show()

# %% [markdown]
# Histogram Plot

# %%
sns.histplot(data =data_Pokemon['Total'],color='salmon')
plt.xlabel=('Total Powers of the Pokemons')
plt.show()

# %% [markdown]
# **Extracting Top 10 powerful Pokemons**

# %%
top_10 = data_Pokemon.sort_values('Total',ascending=False).head(10)

# %%
plt.figure(figsize=(15, 6))
plt.subplot(2,2,1)
sns.barplot(data=top_10,x='Total',y='Name',palette='plasma',legend=False)
plt.title('10 Most powerful Pokemons')
plt.show()
# Out:
# C:\Users\COBUY\AppData\Local\Temp\ipykernel_13528\3173367367.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_10,x='Total',y='Name',palette='plasma',legend=False)

# %% [markdown]
# **Generation Wise the Pokemons that have Maximum Total Power**

# %%
gen=data_Pokemon.groupby('Generation')

# %%
top_in_gen= gen.max('Total')
top_in_gen
# Out:
#               #  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Generation
# 1           151    780  250     190      180      194      130    150
# 2           251    700  255     185      230      165      230    130
# 3           386    780  170     180      230      180      200    180
# 4           493    720  150     170      168      150      150    135
# 5           649    700  165     170      145      170      135    145
# 6           721    700  126     160      184      170      154    126
#
#             Legendary
# Generation
# 1                True
# 2                True
# 3                True
# 4                True
# 5                True
# 6                True

# %%
top_in_gen.reset_index()
# Out:
#    Generation    #  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0           1  151    780  250     190      180      194      130    150
# 1           2  251    700  255     185      230      165      230    130
# 2           3  386    780  170     180      230      180      200    180
# 3           4  493    720  150     170      168      150      150    135
# 4           5  649    700  165     170      145      170      135    145
# 5           6  721    700  126     160      184      170      154    126
#
#    Legendary
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True

# %%
sns.barplot(data=top_in_gen,x='Generation',y='Total',hue=None,palette='crest')
plt.title('Gen-Wise MaxPower')
plt.show()
# Out:
# C:\Users\COBUY\AppData\Local\Temp\ipykernel_13528\137051495.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_in_gen,x='Generation',y='Total',hue=None,palette='crest')

# %% [markdown]
# **Generation Wise the Pokemons that have Minimum Total Power**

# %%
top_in_gen= gen.min('Total')
top_in_gen
# Out:
#               #  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Generation
# 1             1    195  10       5        5       15       20     15
# 2           152    180  20      10       10       10       20      5
# 3           252    190   1      15       20       10       20     10
# 4           387    194  20       5        5       10       30      5
# 5           494    255  30      25       30       15       25     10
# 6           650    200  38      22       33       27       25     23
#
#             Legendary
# Generation
# 1               False
# 2               False
# 3               False
# 4               False
# 5               False
# 6               False

# %%
top_in_gen.reset_index()
# Out:
#    Generation    #  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0           1    1    195  10       5        5       15       20     15
# 1           2  152    180  20      10       10       10       20      5
# 2           3  252    190   1      15       20       10       20     10
# 3           4  387    194  20       5        5       10       30      5
# 4           5  494    255  30      25       30       15       25     10
# 5           6  650    200  38      22       33       27       25     23
#
#    Legendary
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False

# %%
sns.barplot(data=top_in_gen,x='Generation',y='Total',palette='deep')
plt.title('Gen-Wise MinPower')
plt.show()
# Out:
# C:\Users\COBUY\AppData\Local\Temp\ipykernel_13528\3517178139.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_in_gen,x='Generation',y='Total',palette='deep')
